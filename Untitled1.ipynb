# %% [markdown]
# <a href="https://colab.research.google.com/github/CoderJuan21/Project-130/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/procodingclass/PRO-Stars-Dataset-CSVs
# Out:
# Cloning into 'PRO-Stars-Dataset-CSVs'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 26 (delta 10), reused 12 (delta 5), pack-reused 0
# Receiving objects: 100% (26/26), 27.77 KiB | 1.85 MiB/s, done.
# Resolving deltas: 100% (10/10), done.

# %%
import pandas as pd
df = pd.read_csv('/content/PRO-Stars-Dataset-CSVs/total_stars.csv')
df
# Out:
#      Unnamed: 0               Star_name     Distance                  Mass  \
# 0             0                     Sun  0.000015813                     1
# 1             1                  Sirius       0008.6                   2.1
# 2             2                 Canopus         0310                    15
# 3             3          Alpha Centauri       0004.4                   1.1
# 4             4                Arcturus         0037                   1.1
# ..          ...                     ...          ...                   ...
# 249         153  2MASSI J2356547-155310         74.0            0.07636704
# 250         154          WISE 0410+1502         20.0           0.005727528
# 251         155         WISE 0458+6434A         35.9  0.014318820000000001
# 252         156         WISE 0458+6434B         35.9            0.00954588
# 253         157          WISE 1405+5534         25.3  0.028637640000000002
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Star_name', 'Distance', 'Mass', 'Radius', 'Luminosity',
#        'Unnamed: 6', 'Star_name.1', 'Distance.1', 'Mass.1', 'Radius.1'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0', 'Star_name.1', 'Distance.1', 'Mass.1', 'Radius.1', 'Luminosity', 'Unnamed: 6'], axis = 1, inplace = True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-348021875554> in <cell line: 1>()
# ----> 1 df.drop(['Unnamed: 0', 'Star_name.1', 'Distance.1', 'Mass.1', 'Radius.1', 'Luminosity', 'Unnamed: 6'], axis = 1, inplace = True)
#       2 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
final_data = df.dropna()
final_data.to_csv("final_data.csv")
from google.colab import files
files.download("final_data.csv")
